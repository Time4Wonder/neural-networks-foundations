# %% [markdown]
# # Mini-Netz lernt eine Sinus-Funktion
# Ein winziges MLP naehert `y = sin(2x) + 0.5*sin(5x)` an.
# Ziel: Grundlagen verstehen - Daten, Modell, Loss, Gradientenabstieg.

# %%
print("hallo welt")
x = "penis"
# Out:
# hallo welt

# %%
print(x)
